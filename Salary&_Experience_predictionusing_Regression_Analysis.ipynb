# %% [markdown]
# <a href="https://colab.research.google.com/github/harini1703/Salary-Experience-prediction-using-Regression-Analysis/blob/main/Salary%26_Experience_predictionusing_Regression_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **REGRESSION ANALYSIS:**
#
# "Regression analysis isaform of predictive modelling technique which investigates the relationship between independent and dependent variable"
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **IMPORTING LIBRARIES:**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## READING THE DATASET:

# %%
df=pd.read_csv("https://raw.githubusercontent.com/YBI-Foundation/Dataset/main/Salary%20Data.csv")

# %%
df.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Experience Years  Salary
# 0                1.1   39343
# 1                1.2   42774
# 2                1.3   46205
# 3                1.5   37731
# 4                2.0   43525
# 5                2.2   39891
# 6                2.5   48266
# 7                2.9   56642
# 8                3.0   60150
# 9                3.2   54445
# 10               3.2   64445
# 11               3.5   60000
# 12               3.7   57189
# 13               3.8   60200
# 14               3.9   63218
# 15               4.0   55794
# 16               4.0   56957
# 17               4.1   57081
# 18               4.3   59095
# 19               4.5   61111
# 20               4.7   64500
# 21               4.9   67938
# 22               5.1   66029
# 23               5.3   83088
# 24               5.5   82200
# 25               5.9   81363
# 26               6.0   93940
# 27               6.2   91000
# 28               6.5   90000
# 29               6.8   91738
# ...

# %%
df.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
y= df['Salary']

# %%
X = df[[ 'Experience Years'       ]]

# %% [markdown]
# TRAINING THE DATASET:

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=2529,test_size=0.7)

# %%
model=LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 22576.31347881898

# %%
model.coef_
# Out:
# array([10100.90995782])

# %%
x_test
# Out:
# 9      54445
# 13     60200
# 5      39891
# 37    112635
# 23     83088
# 25     81363
# 21     67938
# 24     82200
# 8      60150
# 36    116969
# 15     55794
# 32    113812
# Name: Salary, dtype: int64

# %%
y_test
# Out:
# 29     91738
# 11     60000
# 33    111620
# 16     56957
# 19     61111
# 38    122391
# 27     91000
# 14     63218
# 17     57081
# 12     57189
# 1      42774
# 6      48266
# 28     90000
# 31    101302
# 34    109431
# 20     64500
# 4      43525
# 3      37731
# 18     59095
# 26     93940
# 2      46205
# 22     66029
# 35    105582
# 7      56642
# 39    121872
# 30     98273
# 10     64445
# 0      39343
# Name: Salary, dtype: int64

# %%
y_pred = model.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 4755.22184118834

# %%
sns.regplot(x='Experience Years', y='Salary', data = df)
